-- %%
CREATE EXTERNAL Location if not EXISTS `dlt-circuit-box`
URL 'abfss://circuit-box@dbstoragecerttest.dfs.core.windows.net'
WITH (STORAGE CREDENTIAL ext)
COMMENT 'This is circuit box storage'

-- %%
CREATE catalog if not EXISTS circuit_box
MAnaged location 'abfss://circuit-box@dbstoragecerttest.dfs.core.windows.net'

-- %%
CREATE SCHEMA IF NOT EXISTS circuit_box.landing
MANAGED LOCATION 'abfss://circuit-box@dbstoragecerttest.dfs.core.windows.net/landing'
COMMENT 'This is landing schema'

-- %%
CREATE EXTERNAL VOLUME IF NOT EXISTS circuit_box.landing.circuit_volume
Location 'abfss://circuit-box@dbstoragecerttest.dfs.core.windows.net/landing/operational_data/'
COMMENT 'This is landing volume'

-- %%
%fs ls /Volumes/circuit_box/landing/circuit_volume/addresses/
