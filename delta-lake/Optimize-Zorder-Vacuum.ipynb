-- %%
CREATE TABLE if not EXISTS demo.delta.optimize_company
( company_name String,
Foundation Date, 
Country String
)

-- %%
INSERT into demo.delta.optimize_company
VALUES ('Microsoft', '1975-04-04','USA'),
 ('Apple', '1985-04-04','USA')

-- %%
INSERT into demo.delta.optimize_company
VALUES ('NVIDIA', '1975-04-04','India'),
 ('TESLA', '1985-04-04','UAE')

-- %%
OPTIMIZE demo.delta.optimize_company;

Desc history demo.delta.optimize_company;

-- %%
INSERT into demo.delta.optimize_company
VALUES ('UBS', '1975-04-04','SWZ'),
 ('ENBD', '1985-04-04','UAE'),
 ('Microsoft', '1975-04-04','USA'),
 ('Apple', '1985-04-04','USA')

-- %%
OPTIMIZE demo.delta.optimize_company ZORDER by (company_name)

-- %%
select * from demo.delta.optimize_company

-- %%
ALTER TABLE demo.delta.optimize_company SET TBLPROPERTIES ('delta.deletedFileRetentionDuration' = '0 hours');

VACUUM demo.delta.optimize_company RETAIN 0 HOURS;
