-- %% [markdown]
-- ##  CREATE bronze metastore in hive

-- %%
CREATE SCHEMA if NOT EXISTS hive_metastore.bronze

-- %% [markdown]
-- ## CREATE EXTERNAL TABLE

-- %%
CREATE TABLE IF NOT EXISTS hive_metastore.bronze.refunds
USING JDBC
OPTIONS (
  url "jdbc:sqlserver://gizbo.database.windows.net:1433;database=gizbo-db",
  dbtable "refunds",
  user "gizmo-ad",
  password "Admin@123"
)

-- %%
select * from hive_metastore.bronze.refunds
