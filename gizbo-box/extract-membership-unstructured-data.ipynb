-- %%
select * from binaryFile.`/Volumes/gizmo_box/landing/operational_data/memberships/*`;

-- %%
CREATE or REPLACE view gizmo_box.bronze.v_membership
AS
select * from binaryFile.`/Volumes/gizmo_box/landing/operational_data/memberships/*`;

-- %%
select * from gizmo_box.bronze.v_membership
