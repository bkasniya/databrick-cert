-- %%
CREATE or REPLACE FUNCTION gizmo_box.default.getFullName(first_name STRING, last_name STRING)
RETURNS STRING
RETURN concat(initcap(first_name), ' ', initcap(last_name))

-- %%
select gizmo_box.default.getFullName('john', 'test')
