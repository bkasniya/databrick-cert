-- %% [markdown]
-- # CREATE External Location

-- %%
%fs ls "abfss://gizmo-box@dbstoragecerttest.dfs.core.windows.net/landing/external_data/payments"

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS gizbo_box_cmd url "abfss://gizmo-box@dbstoragecerttest.dfs.core.windows.net/" with (Storage Credential ext) COMMENT "This is create using sql command"

-- %% [markdown]
-- # CREATE CATALOGS

-- %%
show catalogs;

-- %%
CREATE CATALOG IF NOT EXISTS gizmo_box 
MANAGED LOCATION 'abfss://gizmo-box@dbstoragecerttest.dfs.core.windows.net/' 
COMMENT "gizmo box landing catalog"

-- %% [markdown]
-- # CREATE SCHEMAS

-- %%
use catalog gizmo_box;

-- %%
select current_catalog();

-- %%
CREATE SCHEMA IF NOT EXISTS landing 
MANAGED LOCATION 'abfss://gizmo-box@dbstoragecerttest.dfs.core.windows.net/landing'
COMMENT "gizmo box landing schema";

CREATE SCHEMA IF NOT EXISTS bronze 
MANAGED LOCATION 'abfss://gizmo-box@dbstoragecerttest.dfs.core.windows.net/bronze'
COMMENT "gizmo box bronze schema";

CREATE SCHEMA IF NOT EXISTS silver 
MANAGED LOCATION 'abfss://gizmo-box@dbstoragecerttest.dfs.core.windows.net/silver'
COMMENT "gizmo box silver schema";

CREATE SCHEMA IF NOT EXISTS gold 
MANAGED LOCATION 'abfss://gizmo-box@dbstoragecerttest.dfs.core.windows.net/gold'
COMMENT "gizmo box gold schema";

-- %%
show schemas;

-- %% [markdown]
-- # CREATE VOLUME

-- %%
USE CATALOG gizmo_box;

USE SCHEMA landing;

CREATE EXTERNAL VOLUME operational_data 
LOCATION 'abfss://gizmo-box@dbstoragecerttest.dfs.core.windows.net/landing/operational_data'
COMMENT 'This is operational data volume'
