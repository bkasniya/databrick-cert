-- %%
--  File contains invalid records to move to text file
select  *, _metadata.file_path as filepath from json.`/Volumes/gizmo_box/landing/operational_data/orders/`;

-- %% [markdown]
-- Load data as text file

-- %%
select * from text.`/Volumes/gizmo_box/landing/operational_data/orders/`;

-- %%
CREATE or REPLACE view gizmo_box.bronze.v_orders as select * from text.`/Volumes/gizmo_box/landing/operational_data/orders/`;

-- %%
select * from gizmo_box.bronze.v_orders
