# %% [markdown]
# ## Run SQL command using python

# %%
df = spark.sql("select * from json.`/Volumes/gizmo_box/landing/operational_data/customers/customers_2024_10.json`")

df.createTempView("tv_customers")

# %%
# %sql

select * from tv_customers

# %% [markdown]
# ## SPARK READ API

# %%
df = spark.read.format("json").load("/Volumes/gizmo_box/landing/operational_data/customers/customers_2024_10.json")

display(df)

# %% [markdown]
# ## spark.table Function

# %%
df = spark.table("gizmo_box.bronze.v_customer")
display(df)
