-- %%
select * from csv.`/Volumes/gizmo_box/landing/operational_data/addresses/`;

-- select only support comma seperated csvs

-- %%
select * from  read_files('/Volumes/gizmo_box/landing/operational_data/addresses/', 
format => "csv",
header => true,
delimiter => "\t"
)

-- %%
CREATE OR REPLACE VIEW gizmo_box.bronze.v_address 
as 
select * from  read_files('/Volumes/gizmo_box/landing/operational_data/addresses/', 
format => "csv",
header => true,
delimiter => "\t"
)

-- %%
select * from gizmo_box.bronze.v_address
