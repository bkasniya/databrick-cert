-- %% [markdown]
-- ## Extract Customer data from Json

-- %%
%fs ls /Volumes/gizmo_box/landing/operational_data/customers/

-- %% [markdown]
-- ## Query Single File

-- %%
select * from json.`/Volumes/gizmo_box/landing/operational_data/customers/customers_2024_10.json`;

-- %% [markdown]
-- ## Query Multiple file using wildcard

-- %%
select * from json.`/Volumes/gizmo_box/landing/operational_data/customers/customers_2024_*.json`;

-- %% [markdown]
-- ## Query Multiple files from folder

-- %%
select _metadata.file_path as filepath, * from json.`/Volumes/gizmo_box/landing/operational_data/customers/`

-- %% [markdown]
-- ## Create view using heirarchical name

-- %%
CREATE OR REPLACE view gizmo_box.bronze.v_customer 
as
select _metadata.file_path as filepath, * from json.`/Volumes/gizmo_box/landing/operational_data/customers/`

-- %% [markdown]
-- ## Create view as usual

-- %%
use catalog gizmo_box;
use schema bronze;


CREATE OR REPLACE view v_customer 
as
select _metadata.file_path as filepath, * from json.`/Volumes/gizmo_box/landing/operational_data/customers/`

-- %%
select * from v_customer;

-- %%
CREATE OR REPLACE TEMPORARY view temp_v_customer 
as
select _metadata.file_path as filepath, * from json.`/Volumes/gizmo_box/landing/operational_data/customers/`;

CREATE OR REPLACE GLOBAL TEMPORARY view g_temp_v_customer 
as
select _metadata.file_path as filepath, * from json.`/Volumes/gizmo_box/landing/operational_data/customers/`

-- %%
select * from temp_v_customer;
select * from global_temp.g_temp_v_customer;
