-- %% [markdown]
-- ## History Time Travel
--
-- - Query history of table
-- - Query previous version of data
-- - Query data with specific time
-- - Query data with specific version

-- %%
desc history demo.delta.company

-- %% [markdown]
-- Specific time

-- %%
  select * from demo.delta.company TIMESTAMP AS of '2025-07-11T19:42:48.000+00:00'

-- %%
select * from demo.delta.company VERSION AS OF 2

-- %%
RESTORE table demo.delta.company to version as of 1

-- %%
SELECT * FROM demo.delta.company
