-- %%
CREATE SCHEMA if not EXISTS demo.delta
Managed Location "abfss://demo@dbstoragecerttest.dfs.core.windows.net/delta"

-- %%
CREATE TABLE if not EXISTS demo.delta.company
( company_name String,
Foundation Date, 
Country String
)

-- %%
INSERT into demo.delta.company
VALUES ('Microsoft', '1975-04-04','USA'),
 ('Apple', '1985-04-04','USA')

-- %%
INSERT into demo.delta.company
VALUES ('NVIDIA', '1975-04-04','India'),
 ('UBS', '1985-04-04','London')
